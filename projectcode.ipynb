# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df_eeo = pd.read_csv(r"C:/Users/gghus/Downloads/DTSC Project/EEO-4_Reports_20250417.csv")
df_eeo
# Out:
#       Func Code                          Function Description  \
# 0             1  FINANCIAL ADMINISTRATION AND GENERAL CONTROL
# 1             1  FINANCIAL ADMINISTRATION AND GENERAL CONTROL
# 2             1  FINANCIAL ADMINISTRATION AND GENERAL CONTROL
# 3             1  FINANCIAL ADMINISTRATION AND GENERAL CONTROL
# 4             1  FINANCIAL ADMINISTRATION AND GENERAL CONTROL
# ...         ...                                           ...
# 1500         15                                         OTHER
# 1501         15                                         OTHER
# 1502         15                                         OTHER
# 1503         15                                         OTHER
# 1504         15                                         OTHER
#
#                        Employment Status            Job Category  Line No  \
# 0                 1. FULL-TIME EMPLOYEES            OFFICIAL/ADM        6
# ...
